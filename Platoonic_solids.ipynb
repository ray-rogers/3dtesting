# %%
G = tetrahedron((0,-3.5,0), color='blue') + cube((0,-2,0),color=(.25,0,.5))
G += octahedron(color='red') + dodecahedron((0,2,0), color='orange')
G += icosahedron(center=(0,4,0), color='yellow')
G.show(aspect_ratio=[1,1,1])
# Out:
# Graphics3d Object

# %%
octahedron?
# Out:
# Signature:      octahedron(center=(0, 0, 0), size=1, **kwds)
# Docstring:
#    Return an octahedron.
#
#    INPUT:
#
#    * "center" -- (default: (0,0,0))
#
#    * "size" -- (default: 1)
#
#    * "color" -- a string that describes a color; this can also be a
#      list of 3-tuples or strings length 6 or 3, in which case the
#      faces (and oppositive faces) are colored.
#
#    * "opacity" -- (default: 1) if less than 1 then is transparent
#
#    EXAMPLES:
#
#       sage: G = octahedron((1,4,3), color='orange')
#       sage: G += octahedron((0,2,1), size=2, opacity=0.6)
#       sage: G
#       Graphics3d Object
# Init docstring: Initialize self.  See help(type(self)) for accurate signature.
# File:           /opt/sage-9.7/sage-develop/src/sage/misc/decorators.py
# Type:           function

# %%
Φ = (1+sqrt(5.0))/2.0;Φ
# Out:
# 1.61803398874989

# %%
# Out:
# /opt/sage-9.7/sage-develop/local/var/lib/sage/venv-python3.10/lib/python3.10/site-packages/IPython/core/oinspect.py:591: DeprecationWarning: using len on a symbolic expression is deprecated; use method number_of_operands instead
# See https://trac.sagemath.org/29738 for details.
#   info = self.info(obj, oname=oname, info=info, detail_level=detail_level)
# Type:           Expression
# String form:    1/2*sqrt(2) + 1/2
# Length:         2
# File:           /opt/sage-9.7/sage-develop/src/sage/symbolic/expression.pyx
# Docstring:
#    Nearly all expressions are created by calling
#    new_Expression_from_*, but we need to make sure this at least does
#    not leave self._gobj uninitialized and segfault.
# Init docstring:
#    Nearly all expressions are created by calling
#    new_Expression_from_*, but we need to make sure this at least does
#    not leave self._gobj uninitialized and segfault.
# Call docstring:
#    Call the "subs()" on this expression.
#
#    EXAMPLES:
#
#       sage: var('x,y,z')
#       (x, y, z)
#       sage: (x+y)(x=z^2, y=x^y)
#       z^2 + x^y
